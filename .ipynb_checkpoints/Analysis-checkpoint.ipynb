# %%
#Import liabraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import Image

# %% [markdown]
# Open The Data File to a Data Frame and open The Data Set Description file

# %%
#Data set
f = open('slump_test.data',"r")
data = []
for x in f:
    data.append(x)
df = pd.DataFrame(data)
df = df[0].str.split(',', expand=True)
df.iloc[:, -1] = df.iloc[:, -1].apply(lambda x: x.rstrip())
df.columns = df.iloc[0]
df = df.iloc[1:, 1:]
df = df.apply(pd.to_numeric) #convert to numeric format
df = df.drop_duplicates(keep='first') #delete potential duplicates

#Description of the data set
with open('slump_test.names', 'r') as myfile:
    description = myfile.read().replace('\n', ' ').replace('\r', '')

# %% [markdown]
# ### Introduction to the problem

# %% [markdown]
# The compressive strength of concrete is the most common perfomance measure used by engineer in designing buildings and other structures.
#
# **What is the Compressive Strength of Concrete?**
#
# The Compressive Strength of Concreate is performed to check the workability of freshly made concrete. It is measured by breaking cyclindrical concreate specimens in a compression-testing machine:
#
#
# <center>$Compressive Strength = \frac{Failure Load}{Cross-Sectional Area}$</center>
#
# This measure is usually reported in megapascals (MPa) and usually strength requirement for concrete are at an age of 28 days. Compressive Strength of Concrete requirement can vary from **10 MPa** for residential concreates to **50 MPa** and higher for commertial structures. Sometimes higher values are needed for certain applications.
#
# Compressive strength result are primarily used to determine that the concreate mixture as delivered meets the requirement. Strength results can be used for quality control, acceptance of concreate, or even scheduling construction operations.
#
# <img src="test.jpg" width="300" height="300">

# %% [markdown]
# **Why we might want to investigate this field?**
#
# High performance is the most important expectation from concrete which is commonly used in today’s construction technology.
#
# So we face the problem of optimization of the materials used to form the concrete in order to decrease the costs of construction and at the same time meet the workability requirement of concrete.

# %% [markdown]
# ### EDA

# %% [markdown]
# Lets look at the sample of data

# %%
df.head()
# Out:
# 0  Cement   Slag  Fly ash  Water    SP  Coarse Aggr.  Fine Aggr.  SLUMP(cm)  \
# 1   273.0   82.0    105.0  210.0   9.0         904.0       680.0       23.0
# 2   163.0  149.0    191.0  180.0  12.0         843.0       746.0        0.0
# 3   162.0  148.0    191.0  179.0  16.0         840.0       743.0        1.0
# 4   162.0  148.0    190.0  179.0  19.0         838.0       741.0        3.0
# 5   154.0  112.0    144.0  220.0  10.0         923.0       658.0       20.0
#
# 0  FLOW(cm)  Compressive Strength (28-day)(Mpa)
# 1      62.0                               34.99
# 2      20.0                               41.14
# 3      20.0                               41.81
# 4      21.5                               42.08
# 5      64.0                               26.82

# %%
print('The shape of the data set is: {}'.format(df.shape))
df.isnull().sum() == 0 #check if nans are not in specific features
# Out:
# The shape of the data set is: (103, 10)
# 0
# Cement                                True
# Slag                                  True
# Fly ash                               True
# Water                                 True
# SP                                    True
# Coarse Aggr.                          True
# Fine Aggr.                            True
# SLUMP(cm)                             True
# FLOW(cm)                              True
# Compressive Strength (28-day)(Mpa)    True
# dtype: bool

# %%
plt.figure(figsize=(8, 5))
sns.distplot(df['Compressive Strength (28-day)(Mpa)'], bins=50, hist_kws={'alpha': 0.4});

# %% [markdown]
# Outliers detection with boxplot

# %%
features_to_analyse = df.columns[:7]
current_palette = sns.color_palette("Blues")

fig, axes = plt.subplots(round(len(features_to_analyse)/4), 4, figsize = (18, 8))

for i, ax in enumerate(fig.axes):
    if i < len(features_to_analyse):
        sns.boxplot(x=features_to_analyse[i], data = df, ax = ax, orient = 'v', color = current_palette[i])
fig.delaxes(ax = axes[1,3])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-233-0979c384d2ff> in <module>
#       6 for i, ax in enumerate(fig.axes):
#       7     if i < len(features_to_analyse):
# ----> 8         sns.boxplot(x=features_to_analyse[i], data = df, ax = ax, orient = 'v', color = current_palette[i])
#       9 fig.delaxes(ax = axes[1,3])
#
# IndexError: list index out of range

# %%
sns.boxplot(x="day", y="total_bill", data=tips)

# %%
df.iloc[:, -3]
# Out:
# 1      23.00
# 2       0.00
# 3       1.00
# 4       3.00
# 5      20.00
# 6      23.00
# 7       0.00
# 8      14.50
# 9      15.50
# 10     19.00
# 11     24.50
# 12     23.75
# 13     25.50
# 14     17.00
# 15     14.50
# 16     23.50
# 17     12.00
# 18     25.00
# 19     20.50
# 20     15.00
# 21     20.00
# 22     13.00
# 23      0.00
# 24     18.00
# 25      0.00
# 26     23.75
# 27     25.00
# 28     26.50
# 29     16.00
# 30     21.50
#        ...
# 74     24.00
# 75     24.00
# 76     23.50
# 77     12.00
# 78     23.00
# 79     16.25
# 80     23.50
# 81     24.50
# 82     21.00
# 83     24.00
# 84     21.25
# 85     23.50
# 86     24.50
# 87     25.00
# 88     26.50
# 89      9.50
# 90     14.50
# 91     14.50
# 92     17.00
# 93     25.00
# 94      0.00
# 95      0.00
# 96      0.00
# 97     27.50
# 98     25.00
# 99      0.00
# 100     2.00
# 101     0.00
# 102    27.50
# 103    29.00
# Name: SLUMP(cm), Length: 103, dtype: float64

# %%
sns.pairplot(df.iloc[:, -3])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-204-b2c79c2800ef> in <module>
# ----> 1 sns.pairplot(df.iloc[:, -3])
#
# ~/anaconda3/envs/py37/lib/python3.6/site-packages/seaborn/axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, dropna, plot_kws, diag_kws, grid_kws, size)
#    2068         raise TypeError(
#    2069             "'data' must be pandas DataFrame object, not: {typefound}".format(
# -> 2070                 typefound=type(data)))
#    2071
#    2072     if plot_kws is None:
#
# TypeError: 'data' must be pandas DataFrame object, not: <class 'pandas.core.series.Series'>

# %%
features_to_analyse = df.columns[:8]

# %%
df.columns
# Out:
# Index(['Cement', 'Slag', 'Fly ash', 'Water', 'SP', 'Coarse Aggr.',
#        'Fine Aggr.', 'SLUMP(cm)', 'FLOW(cm)',
#        'Compressive Strength (28-day)(Mpa)'],
#       dtype='object', name=0)

# %%
fig, ax = plt.subplots(round(len(analyse) / 3), 3, figsize = (18, 12))

for i, ax in enumerate(fig.axes):
    if i < len(features_to_analyse) - 1:
        sns.regplot(x=features_to_analyse[i],y='Compressive Strength (28-day)(Mpa)', data = df, ax=ax)
